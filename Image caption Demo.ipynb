# %%
import sys, os
from caption_generator import *
from utils.config import Config
# %matplotlib inline
# Out:
# /Users/yashwanthreddyvirupaksha/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
args= {"mode": "test", "resume":0, "load_image":1,"saveencoder":0, "savedecoder":0}
config =Config(args)
model = Caption_Generator(config)
# Out:
# Loading previous checkpoint.
# 4751
# INFO:tensorflow:Restoring parameters from ./model/model.ckpt-73644

# %%
path="/Users/yashwanthreddyvirupaksha/Desktop/Image-Caption/Dataset/test_images/"
files=sorted(os.listdir(path))
files=[path+f for f in files]

# %%
for f in files:
    if os.path.splitext(f)[1] in [".png",".jpg",".jpeg"]:
        model.decode(f)
# Out:
# [[0.01975605 0.02626786 0.15623988 ... 0.03662938 0.         0.532492  ]]
# loaded_image
# [[0.26897794 0.54718447 0.0454716  ... 0.50911766 0.11343735 0.53575045]]
# loaded_image
# [[0.01155761 0.13052396 0.01030198 ... 0.06010273 0.2750633  0.19101775]]
# loaded_image
# [[0.01946265 0.30521527 0.06326441 ... 0.02838186 0.06091399 0.92471683]]
# loaded_image
# [[0.00326358 0.01471451 0.19959982 ... 0.15785748 0.09549257 0.34341258]]
# loaded_image
